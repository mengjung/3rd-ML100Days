# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %% [markdown]
# # [作業目標]
# - 熟悉更多的 Python 資料操作

# %% [markdown]
# # [作業重點]
# - 列出資料的大小 (In[4], Hint : shape)
# - 列出所有欄位 (In[5], 有多種寫法)
# - 擷取部分資料 (In[6], Hint : loc 或 iloc)

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data =r'C:\Users\Song\Desktop\day4\data\application_train.csv'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(r'C:\Users\Song\Desktop\day4\data\application_train.csv')
# Out:
# Path of read in data: C:\Users\Song\Desktop\day4\data\application_train.csv\application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
#資料的 row 數以及 column 數 (rows,columns)
app_train.shape
# Out:
# (307511, 122)

# %% [markdown]
# #### 列出所有欄位

# %%
#列出所有欄位
app_train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %% [markdown]
# #### 截取部分資料

# %%
#截取部分資料
app_train[['NAME_CONTRACT_TYPE','CODE_GENDER', 'NAME_INCOME_TYPE']]
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER      NAME_INCOME_TYPE
# 0              Cash loans           M               Working
# 1              Cash loans           F         State servant
# 2         Revolving loans           M               Working
# 3              Cash loans           F               Working
# 4              Cash loans           M               Working
# 5              Cash loans           M         State servant
# 6              Cash loans           F  Commercial associate
# 7              Cash loans           M         State servant
# 8              Cash loans           F             Pensioner
# 9         Revolving loans           M               Working
# 10             Cash loans           F               Working
# 11             Cash loans           F             Pensioner
# 12             Cash loans           F               Working
# 13             Cash loans           M               Working
# 14             Cash loans           F               Working
# ...

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子

# %%
#在CONTRACT_TYPE、INCOME_TYPE下其他資料(AMT_INCOME)的關係
app_train.groupby(['NAME_CONTRACT_TYPE', 'NAME_INCOME_TYPE']).mean()
# Out:
#                                             SK_ID_CURR    TARGET  \
# NAME_CONTRACT_TYPE NAME_INCOME_TYPE
# Cash loans         Commercial associate  278413.318513  0.078395
#                    Maternity leave       395252.500000  1.000000
#                    Pensioner             278527.945146  0.054661
#                    State servant         278602.512250  0.059891
#                    Student               239290.866667  0.000000
#                    Unemployed            260136.933333  0.533333
#                    Working               277788.286472  0.099433
# Revolving loans    Businessman           275396.900000  0.000000
#                    Commercial associate  277468.897928  0.046453
#                    Maternity leave       275371.000000  0.000000
#                    Pensioner             277860.665776  0.041555
#                    State servant         282151.613283  0.032673
#                    Student               347614.333333  0.000000
# ...
